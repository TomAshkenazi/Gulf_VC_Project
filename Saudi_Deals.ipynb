# %%
import pandas as pd

# %%
Kaust_File = "Saudi_Deals/Kaust_Deals.xlsx"
Kaust_1 = pd.read_excel(Kaust_File, header=7)
Kaust = pd.DataFrame(Kaust_1)
Kaust = Kaust[Kaust['Deal ID'].notna()]
fund1="KAUST Innovation Fund"
Kaust['Fund'] = fund1
Kaust
# Out:
#        Deal ID       Company Name Series   VC Round Current Business Status  \
# 0   117348-40T              UnitX    NaN  1st Round      Generating Revenue
# 1    29300-95T             Acadox    NaN  1st Round      Generating Revenue
# 2    72771-94T            Agendat    NaN  1st Round         Out of Business
# 3    99166-24T             alBasr    NaN  1st Round                 Startup
# 4   117239-41T             alBasr    NaN        NaN                 Startup
# ..         ...                ...    ...        ...                     ...
# 82  130012-21T              UnitX    NaN        NaN      Generating Revenue
# 83   72770-14T  Visual Experience    NaN  1st Round      Generating Revenue
# 84  117379-45T  Visual Experience    NaN  2nd Round      Generating Revenue
# 85   72780-31T            WebGLot    NaN  2nd Round      Generating Revenue
# 86  117380-26T            WebGLot    NaN  1st Round      Generating Revenue
#
# ...

# %%
Aramco_file = "Saudi_Deals/Aramco_Deals.xlsx"
Aramco_1 = pd.read_excel(Aramco_file, header=7)
Aramco = pd.DataFrame(Aramco_1)
Aramco = Aramco[Aramco['Deal ID'].notna()]
fund2="Saudi Aramco Energy Ventures"
Aramco['Fund'] = fund2
Aramco
# Out:
#        Deal ID     Company Name    Series   VC Round  \
# 0   115649-20T    Desktop Metal  Series E  6th Round
# 1    90371-98T    Desktop Metal  Series D  4th Round
# 2    81244-45T    Desktop Metal  Series C  3rd Round
# 3   138986-11T         Parsable  Series D  6th Round
# 4   118466-20T      908 Devices  Series E  5th Round
# ..         ...              ...       ...        ...
# 61  102474-19T  Vere Technology       NaN        NaN
# 62   81696-52T       Well-SENSE       NaN  1st Round
# 63  132531-76T       Well-SENSE  Series C  3rd Round
# 64  105174-01T    Xage Security  Series A  2nd Round
# 65   26297-47T           Zilift       NaN  3rd Round
#
#               Current Business Status             Primary Industry Group  \
# 0                  Generating Revenue                  Computer Hardware
# 1                  Generating Revenue                  Computer Hardware
# 2                  Generating Revenue                  Computer Hardware
# ...

# %%
Vision_file = "Saudi_Deals/Vision_Deals.xlsx"
Vision_1 = pd.read_excel(Vision_file, header=7)
Vision = pd.DataFrame(Vision_1)
Vision = Vision[Vision['Deal ID'].notna()]
fund3="Vision Ventures (Dammam)"
Vision['Fund'] = fund3
Vision
# Out:
#        Deal ID          Company Name     Series   VC Round  \
# 0   134163-46T                 Sibly   Series A  2nd Round
# 1   110447-65T                 Salla        NaN  1st Round
# 2   135258-13T                360VUZ   Series A  2nd Round
# 3    91652-41T                Bayzat  Series A1  3rd Round
# 4   135296-11T               Brimore   Series A  3rd Round
# 5   114530-95T                Buseet        NaN  1st Round
# 6   119981-98T                Buseet        NaN  2nd Round
# 7   100988-56T             Caramella        NaN  1st Round
# 8   135220-60T               Cartlow        NaN  1st Round
# 9   126545-23T                Chefaa        NaN  2nd Round
# 10  127060-39T                Dabchy        NaN  1st Round
# 11  122488-12T                  Dhad        NaN  2nd Round
# 12  114317-92T       Gathern Holding        NaN  1st Round
# 13  114922-18T                 Geeks        NaN  2nd Round
# 14   99496-81T             Gyrocraft        NaN  1st Round
# ...

# %%
Raed_file = "Saudi_Deals/Ra'ed Deals.xlsx"
Raed_1 = pd.read_excel(Raed_file, header=7)
Raed = pd.DataFrame(Raed_1)
Raed = Raed[Raed['Deal ID'].notna()]
fund4="Raed Ventures"
Raed['Fund'] = fund4
Raed
# Out:
#        Deal ID          Company Name    Series   VC Round  \
# 0    81738-73T                Fetchr  Series B  3rd Round
# 1   110447-65T                 Salla       NaN  1st Round
# 2   103899-79T               Aqarmap       NaN  2nd Round
# 3    78135-76T                Bayzat  Series A  2nd Round
# 4   124348-69T                Bayzat  Series B  4th Round
# 5   101028-43T        Crowd Analyzer       NaN  1st Round
# 6   110446-03T        Crowd Analyzer       NaN  2nd Round
# 7   122488-12T                  Dhad       NaN  2nd Round
# 8    37292-59T              Eventtus       NaN  1st Round
# 9   157845-97T              Eventtus       NaN  2nd Round
# 10   94824-37T               Foodics  Series A  2nd Round
# 11  114331-96T               Foodics       NaN  1st Round
# 12   99246-52T          Golden Scent       NaN  1st Round
# 13  138697-48T     Lean Technologies       NaN  2nd Round
# 14   97863-40T                Malaeb       NaN  2nd Round
# ...

# %%
Waed_file = "Saudi_Deals/Waed_Deals.xlsx"
Waed_1 = pd.read_excel(Waed_file, header=7)
Waed = pd.DataFrame(Waed_1)
Waed = Waed[Waed['Deal ID'].notna()]
fund5="Wa'ed Ventures"
Waed['Fund'] = fund5
Waed
# Out:
#        Deal ID                                   Company Name    Series  \
# 0   117348-40T                                          UnitX       NaN
# 1   120150-91T                    Arabian Calibration Company       NaN
# 2    92719-99T                               Arabian Robotics       NaN
# 3   120147-13T                                         Averos       NaN
# 4    57373-39T                                      FalconViz       NaN
# 5    86802-49T                  Geophysical Equipment Factory       NaN
# 6   116182-09T                                         GetMuv       NaN
# 7    99246-52T                                   Golden Scent       NaN
# 8   118734-49T                                   Golden Scent       NaN
# 9   133596-19T                                   Golden Scent       NaN
# 10  137260-18T                          Grintafy Technologies       NaN
# 11  121661-11T                                       Hazen.ai       NaN
# ...

# %%
RiyadhValley_file = "Saudi_Deals/Riyadh_Valley_Deals.xlsx"
RiyadhValley_1 = pd.read_excel(RiyadhValley_file, header=7)
RiyadhValley = pd.DataFrame(RiyadhValley_1)
RiyadhValley = RiyadhValley[RiyadhValley['Deal ID'].notna()]
fund6="Riyadh Valley Company"
RiyadhValley['Fund'] = fund6
RiyadhValley
# Out:
#        Deal ID                      Company Name    Series   VC Round  \
# 0    35879-95T                   Beamreach Solar  Series D  5th Round
# 1    67300-57T                     Aquion Energy  Series F  7th Round
# 2   101388-34T                         Prokarium  Series A  3rd Round
# 3    66705-94T                           GSVlabs  Series B  6th Round
# 4   128369-62T                        SecuLetter  Series B  4th Round
# 5    78914-17T  Saudi Health Information Systems       NaN        NaN
# 6    97742-26T        Advanced Dental Technology       NaN  1st Round
# 7    78910-12T                 Aser Technologies       NaN  1st Round
# 8    38153-98T    Avidity Biosciences (NAS: RNA)  Series B  2nd Round
# 9    78464-44T                          Calltech       NaN  1st Round
# 10  114465-07T               Fastned (AMS: FAST)       NaN  1st Round
# 11   78460-48T            GLM (Electric Vehicle)  Series B  2nd Round
# ...

# %%
N2V_file = "Saudi_Deals/N2V_Deals.xlsx"
N2V_1 = pd.read_excel(N2V_file, header=7)
N2V = pd.DataFrame(N2V_1)
N2V = N2V[N2V['Deal ID'].notna()]
fund7="N2V"
N2V['Fund'] = fund7
N2V
# Out:
#       Deal ID             Company Name  Series   VC Round  \
# 0   36790-66T                  Aqarmap     NaN  1st Round
# 1   36793-09T  Discover Digital Arabia     NaN        NaN
# 2   36792-82T             EcommerceSEA     NaN  1st Round
# 3   36793-36T                Electrony     NaN  1st Round
# 4   36795-70T                  GamesXP     NaN  1st Round
# 5   36805-96T                 GameTako     NaN  1st Round
# 6   36819-10T               Hawaaworld     NaN  1st Round
# 7   36840-97T                   iAraby     NaN  1st Round
# 8   36842-41T                  Mjalati     NaN  1st Round
# 9   36842-32T                  N2VLabs     NaN  1st Round
# 10  36849-16T            Net Advantage     NaN  1st Round
# 11  36842-50T                  OneCard     NaN  1st Round
# 12  36844-75T                     Qaym     NaN  1st Round
# 13  36846-82T                    SNSEO     NaN  1st Round
# 14  36851-05T                StartAppz     NaN  1st Round
# ...

# %%
RiyadhTaqnia_File = "Saudi_Deals/Riyadh_Taqnia_Deals.xlsx"
RiyadhTaqnia_1 = pd.read_excel(RiyadhTaqnia_File, header=7)
RiyadhTaqnia = pd.DataFrame(RiyadhTaqnia_1)
RiyadhTaqnia = RiyadhTaqnia[RiyadhTaqnia['Deal ID'].notna()]
fund8="Riyadh Taqnia Fund"
RiyadhTaqnia['Fund'] = fund8
RiyadhTaqnia
# Out:
#        Deal ID            Company Name     Series   VC Round  \
# 0   124440-31T                  Arabot        NaN  1st Round
# 1   128125-36T                    B8ak        NaN  1st Round
# 2    95140-99T                 Beehive   Series A  1st Round
# 3   116966-08T                 Beehive   Series B  2nd Round
# 4   127905-85T            Dokkan Afkar  Series A2  2nd Round
# 5   127921-78T            Dokkan Afkar   Series B  3rd Round
# 6   127934-92T                  Eureka   Series B  2nd Round
# 7    94824-37T                 Foodics   Series A  2nd Round
# 8   127911-43T                 Foodics        NaN  3rd Round
# 9   123928-48T                  Haseel        NaN  1st Round
# 10  128126-62T                    Mile        NaN  1st Round
# 11   84975-13T               Souqalmal  Series B2  3rd Round
# 12  124582-96T               Souqalmal   Series C  4th Round
# 13  128129-50T  Sure Global Technology        NaN  1st Round
# ...

# %%
Sabic_file = "Saudi_Deals/SABIC_Deals.xlsx"
Sabic_1 = pd.read_excel(Sabic_file, header=7)
Sabic = pd.DataFrame(Sabic_1)
Sabic = Sabic[Sabic['Deal ID'].notna()]
fund9="SABIC Ventures"
Sabic['Fund'] = fund9
Sabic
# Out:
#        Deal ID            Company Name     Series   VC Round  \
# 0    19799-92T    Supply Chain Connect   Series D  4th Round
# 1   112300-12T                    MTPV   Series C  6th Round
# 2    22136-05T                 Segetis   Series C  3rd Round
# 3    24670-99T      FibeRio Technology   Series C  3rd Round
# 4    35664-94T                    MTPV  Series B1  5th Round
# 5   136616-23T       VOID Technologies        NaN  1st Round
# 6    52601-41T                7AC Tech   Series C  4th Round
# 7   110892-79T           FLEx Lighting        NaN  1st Round
# 8    22469-95T               Vitriflex   Series B  2nd Round
# 9   117389-62T                Mallinda   Series A  2nd Round
# 10   87602-86T  Airborne International        NaN  3rd Round
# 11  139079-08T  Airborne International        NaN  4th Round
# 12  127209-61T                   Imtex        NaN  2nd Round
# 13   26341-39T   inpro (IT & Services)        NaN  1st Round
# ...

# %%
Hala_file = "Saudi_Deals/Hala_Deals.xlsx"
Hala_1 = pd.read_excel(Hala_file, header=7)
Hala = pd.DataFrame(Hala_1)
Hala = Hala[Hala['Deal ID'].notna()]
fund10="Hala Ventures"
Hala['Fund'] = fund10
Hala
# Out:
#        Deal ID          Company Name    Series   VC Round  \
# 0   135258-13T                360VUZ  Series A  2nd Round
# 1   119981-98T                Buseet       NaN  2nd Round
# 2   121216-15T            Democrance       NaN  3rd Round
# 3   102367-54T      Enhance Ventures       NaN  1st Round
# 4   135129-97T              Eventtus       NaN  4th Round
# 5   114922-18T                 Geeks       NaN  2nd Round
# 6   121221-82T                 Lamsa       NaN  3rd Round
# 7   103347-01T               MAGNiTT       NaN  2nd Round
# 8   114981-31T         PointCheckout       NaN  1st Round
# 9   112204-81T             POSRocket       NaN  2nd Round
# 10  111421-63T  Sarwa Digital Wealth       NaN  2nd Round
# 11   90235-72T              Telfaz11  Series A  1st Round
#
#    Current Business Status    Primary Industry Group  \
# 0       Generating Revenue                  Software
# 1       Generating Revenue            Transportation
# ...

# %%
STV_file = "Saudi_Deals/STV_Deals.xlsx"
STV_1 = pd.read_excel(STV_file, header=7)
STV = pd.DataFrame(STV_1)
STV = STV[STV['Deal ID'].notna()]
fund11="STV"
STV['Fund'] = fund11
STV
# Out:
#        Deal ID          Company Name     Series   VC Round  \
# 0   103510-09T                Careem   Series F  6th Round
# 1   109567-99T        Proof (Austin)        NaN  1st Round
# 2   132139-81T               Firefly  Series A3  5th Round
# 3   119441-26T                Mrsool   Series A  1st Round
# 4   134511-85T           Nana Direct   Series B  3rd Round
# 5   120240-37T          Noon Academy   Series A  1st Round
# 6   138515-23T          Noon Academy        NaN  2nd Round
# 7    90235-72T              Telfaz11   Series A  1st Round
# 8   119944-27T  TruKKer Technologies   Series A  3rd Round
# 9   112984-84T              Unifonic   Series A  1st Round
# 10  111911-86T               Vezeeta   Series C  4th Round
# 11  131699-17T               Vezeeta   Series D  5th Round
#
#    Current Business Status Primary Industry Group  \
# 0       Generating Revenue         Transportation
# 1       Generating Revenue    Commercial Services
# ...

# %%
funds = [Kaust,Aramco,Vision,Raed,Waed,RiyadhValley,N2V,RiyadhTaqnia,Sabic,Hala,STV]
all_Saudi_deals = pd.concat(funds)
all_Saudi_deals
# Out:
#        Deal ID          Company Name    Series   VC Round  \
# 0   117348-40T                 UnitX       NaN  1st Round
# 1    29300-95T                Acadox       NaN  1st Round
# 2    72771-94T               Agendat       NaN  1st Round
# 3    99166-24T                alBasr       NaN  1st Round
# 4   117239-41T                alBasr       NaN        NaN
# ..         ...                   ...       ...        ...
# 7    90235-72T              Telfaz11  Series A  1st Round
# 8   119944-27T  TruKKer Technologies  Series A  3rd Round
# 9   112984-84T              Unifonic  Series A  1st Round
# 10  111911-86T               Vezeeta  Series C  4th Round
# 11  131699-17T               Vezeeta  Series D  5th Round
#
#    Current Business Status Primary Industry Group  \
# 0       Generating Revenue               Software
# 1       Generating Revenue               Software
# 2          Out of Business               Software
# 3                  Startup    Commercial Services
# ...

# %%
SAUDI_ARABIA_DEALS = all_Saudi_deals.reset_index(drop=True)

# %%
SAUDI_ARABIA_DEALS
# Out:
#         Deal ID          Company Name    Series   VC Round  \
# 0    117348-40T                 UnitX       NaN  1st Round
# 1     29300-95T                Acadox       NaN  1st Round
# 2     72771-94T               Agendat       NaN  1st Round
# 3     99166-24T                alBasr       NaN  1st Round
# 4    117239-41T                alBasr       NaN        NaN
# ..          ...                   ...       ...        ...
# 342   90235-72T              Telfaz11  Series A  1st Round
# 343  119944-27T  TruKKer Technologies  Series A  3rd Round
# 344  112984-84T              Unifonic  Series A  1st Round
# 345  111911-86T               Vezeeta  Series C  4th Round
# 346  131699-17T               Vezeeta  Series D  5th Round
#
#     Current Business Status Primary Industry Group  \
# 0        Generating Revenue               Software
# 1        Generating Revenue               Software
# 2           Out of Business               Software
# ...

# %%
country ="Saudi Arabia"
SAUDI_ARABIA_DEALS["Fund's Country"] = country
SAUDI_ARABIA_DEALS
# Out:
#         Deal ID          Company Name    Series   VC Round  \
# 0    117348-40T                 UnitX       NaN  1st Round
# 1     29300-95T                Acadox       NaN  1st Round
# 2     72771-94T               Agendat       NaN  1st Round
# 3     99166-24T                alBasr       NaN  1st Round
# 4    117239-41T                alBasr       NaN        NaN
# ..          ...                   ...       ...        ...
# 342   90235-72T              Telfaz11  Series A  1st Round
# 343  119944-27T  TruKKer Technologies  Series A  3rd Round
# 344  112984-84T              Unifonic  Series A  1st Round
# 345  111911-86T               Vezeeta  Series C  4th Round
# 346  131699-17T               Vezeeta  Series D  5th Round
#
#     Current Business Status Primary Industry Group  \
# 0        Generating Revenue               Software
# 1        Generating Revenue               Software
# 2           Out of Business               Software
# ...

# %%
pd.set_option('display.max_columns', None)

# %%
SAUDI_ARABIA_DEALS['Deal Size'] = SAUDI_ARABIA_DEALS['Post Valuation']*(SAUDI_ARABIA_DEALS['% Acquired']/100)
SAUDI_ARABIA_DEALS
# Out:
#         Deal ID          Company Name    Series   VC Round  \
# 0    117348-40T                 UnitX       NaN  1st Round
# 1     29300-95T                Acadox       NaN  1st Round
# 2     72771-94T               Agendat       NaN  1st Round
# 3     99166-24T                alBasr       NaN  1st Round
# 4    117239-41T                alBasr       NaN        NaN
# ..          ...                   ...       ...        ...
# 342   90235-72T              Telfaz11  Series A  1st Round
# 343  119944-27T  TruKKer Technologies  Series A  3rd Round
# 344  112984-84T              Unifonic  Series A  1st Round
# 345  111911-86T               Vezeeta  Series C  4th Round
# 346  131699-17T               Vezeeta  Series D  5th Round
#
#     Current Business Status Primary Industry Group  \
# 0        Generating Revenue               Software
# 1        Generating Revenue               Software
# 2           Out of Business               Software
# ...

# %%
SAUDI_ARABIA_DEALS.to_csv("SAUDI_ARABIA_DEALS.csv")
